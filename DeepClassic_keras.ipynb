# %% [markdown]
# # DeepClassic

# %% [markdown]
# Reference
# * [Asking RNNs+LTSMs: What Would Mozart Write?](http://www.wise.io/tech/asking-rnn-and-ltsm-what-would-mozart-write)

# %% [markdown]
# ## music21 UserSetting
# * http://web.mit.edu/music21/doc/tutorials/environment.html#environment
# * [music21](https://gist.github.com/Vesnica/f8862277e4e3a27593f4ca300eedf07e)

# %% [markdown]
# ### Install
#
#       sudo apt install musescore scipy timidity lilypond

# %%
from music21 import *

# %%
us = environment.UserSettings()
us.getSettingsPath()
# Out:
# '/home/carnd/.music21rc'

# %%
#us["musicxmlPath"] = "/usr/bin/gedit"
us["musicxmlPath"] = "/usr/bin/mscore"
us["midiPath"] = "/usr/bin/timidity"
us["showFormat"] = "lilypond"
us["writeFormat"] = "lilypond"
us["musescoreDirectPNGPath"] = "/usr/bin/mscore"

# %% [markdown]
# ## Prepare Data

# %%
# !mkdir composer

# %%
import glob
REP="@\n"
def trim_metadata(output_path, glob_path):
    comp_txt = open(output_path,"w")
    ll = glob.glob(glob_path)
    for song in ll:
        lines = open(song,"r").readlines()
        out = []
        found_first = False
        for l in lines:
            if l.startswith("="):
                ## new measure, replace the measure with the @ sign, not part of humdrum
                out.append(REP)
                found_first = True
                continue
            if not found_first:
                ## keep going until we find the end of the header and metadata
                continue
            if l.startswith("!"):
                ## ignore comments
                continue
            out.append(l)
        comp_txt.writelines(out)
    comp_txt.close()

# %% [markdown]
# ### Get kern data from github database
# *  [automata/ana-music: Automatic analysis of classical music for generative composition](https://github.com/automata/ana-music)

# %%
# !git clone https://github.com/automata/ana-music.git
# Out:
# Cloning into 'ana-music'...
# remote: Counting objects: 1876, done.
# remote: Compressing objects: 100% (1576/1576), done.
# remote: Total 1876 (delta 240), reused 1876 (delta 240), pack-reused 0
# Receiving objects: 100% (1876/1876), 8.55 MiB | 5.47 MiB/s, done.
# Resolving deltas: 100% (240/240), done.
# Checking connectivity... done.

# %%
composers = ["mozart","beethoven","chopin","scarlatti","haydn"]
for composer in composers:
    output_path = "composer/" + composer + ".txt"
    glob_path = "ana-music/corpus/{composer}/*.krn".format(composer=composer)
    trim_metadata(output_path, glob_path)

# %%
# !ls composer/*.txt
# Out:
# composer/beethoven.txt	composer/haydn.txt   composer/scarlatti.txt
# composer/chopin.txt	composer/mozart.txt

# %% [markdown]
# ### Get Data from KernScore
# * [KernScores](http://kern.humdrum.org/)

# %%
# %mkdir kernscore
# %mkdir kernscore/bach

# %%
from urllib.request import urlopen
for i in range(1,15+1):
    filename = "inven{0:02d}.krn".format(i)
    file = urlopen("http://kern.humdrum.org/cgi-bin/ksdata?l=osu/classical/bach/inventions&file=%s&f=kern"%filename)
    with open("kernscore/bach/"+filename,'wb') as output:
        output.write(file.read())

# %%
output_path = "composer/bach.txt"
glob_path = "kernscore/bach/*.krn"
trim_metadata(output_path, glob_path)

# %% [markdown]
# ## Setup

# %%
import numpy as np

# %%
filename = 'composer/bach.txt'
with open(filename, 'r') as f:
    text=f.read()
vocab = set(text)

# %%
text[:50]
# Out:
# '@\n4.r\t16dL\n.\t16e\n.\t16f\n.\t16g\n.\t16a\n.\t16b-J\n@\n4.r\t1'

# %%
chars = sorted(list(set(text)))
vocab_size = len(vocab)
vocab_size
# Out:
# 43

# %%
char_indices = dict((c, i) for i, c in enumerate(vocab))
indices_char = dict((i, c) for i, c in enumerate(vocab))

# %%
idx = [char_indices[c] for c in text]

# %%
idx[:10]
# Out:
# [15, 3, 2, 16, 0, 40, 41, 21, 26, 13]

# %% [markdown]
# ## Preprocess

# %%
maxlen = 1
sentences = []
next_chars = []
for i in range(0, len(idx) - maxlen+1):
    sentences.append(idx[i: i + maxlen])
    next_chars.append(idx[i+1: i+maxlen+1])
print('nb sequences:', len(sentences))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2796baea6dd1> in <module>()
#       2 sentences = []
#       3 next_chars = []
# ----> 4 for i in range(0, len(idx) - maxlen+1):
#       5     sentences.append(idx[i: i + maxlen])
#       6     next_chars.append(idx[i+1: i+maxlen+1])
#
# NameError: name 'idx' is not defined

# %%
sentences = np.concatenate([[np.array(o)] for o in sentences[:-6]])
next_chars = np.concatenate([[np.array(o)] for o in next_chars[:-6]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c8020b1f0cbb> in <module>()
# ----> 1 batches = get_batches(encoded, 10, 50)
#       2 x, y = next(batches)
#
# NameError: name 'encoded' is not defined

# %%
sentences.shape, next_chars.shape
# Out:
# ((46468, 1), (46468, 1))

# %% [markdown]
# ## Build Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Embedding, LSTM, TimeDistributed, Activation
from keras.layers.core import Dense, Dropout
from keras.optimizers import Adam

# %%
n_fac = 24

# %%
model=Sequential([
        Embedding(vocab_size, n_fac, input_length=maxlen),
        LSTM(units=512, input_shape=(n_fac,),return_sequences=True, dropout=0.2, recurrent_dropout=0.2,
             implementation=2),
        Dropout(0.2),
        LSTM(512, return_sequences=True, dropout=0.2, recurrent_dropout=0.2,
             implementation=2),
        Dropout(0.2),
        TimeDistributed(Dense(vocab_size)),
        Activation('softmax')
    ])

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam())

# %% [markdown]
# ##  Training

# %%
model.fit(sentences, np.expand_dims(next_chars,-1), batch_size=64, epochs=100)
# Out:
# Epoch 1/100
# 46468/46468 [==============================] - 12s - loss: 1.4329
# Epoch 2/100
# 46468/46468 [==============================] - 12s - loss: 1.4313
# Epoch 3/100
# 46468/46468 [==============================] - 12s - loss: 1.4308
# Epoch 4/100
# 46468/46468 [==============================] - 12s - loss: 1.4303
# Epoch 5/100
# 46468/46468 [==============================] - 12s - loss: 1.4288
# Epoch 6/100
# 46468/46468 [==============================] - 12s - loss: 1.4282
# Epoch 7/100
# 46468/46468 [==============================] - 12s - loss: 1.4285
# Epoch 8/100
# 46468/46468 [==============================] - 12s - loss: 1.4272
# Epoch 9/100
# 46468/46468 [==============================] - 12s - loss: 1.4256
# Epoch 10/100
# 46468/46468 [==============================] - 12s - loss: 1.4258
# Epoch 11/100
# 46468/46468 [==============================] - 12s - loss: 1.4254
# Epoch 12/100
# 46468/46468 [==============================] - 12s - loss: 1.4239
# Epoch 13/100
# 46468/46468 [==============================] - 12s - loss: 1.4238
# Epoch 14/100
# 46468/46468 [==============================] - 12s - loss: 1.4234
# Epoch 15/100
# 46468/46468 [==============================] - 12s - loss: 1.4229
# Epoch 16/100
# 46468/46468 [==============================] - 12s - loss: 1.4226
# Epoch 17/100
# 46468/46468 [==============================] - 12s - loss: 1.4217
# Epoch 18/100
# 46468/46468 [==============================] - 12s - loss: 1.4211
# Epoch 19/100
# 46468/46468 [==============================] - 12s - loss: 1.4206
# Epoch 20/100
# 46468/46468 [==============================] - 12s - loss: 1.4225
# Epoch 21/100
# 46468/46468 [==============================] - 12s - loss: 1.4194
# Epoch 22/100
# 46468/46468 [==============================] - 12s - loss: 1.4197
# Epoch 23/100
# 46468/46468 [==============================] - 12s - loss: 1.4195
# Epoch 24/100
# 46468/46468 [==============================] - 12s - loss: 1.4188
# Epoch 25/100
# 46468/46468 [==============================] - 12s - loss: 1.4182
# Epoch 26/100
# 46468/46468 [==============================] - 12s - loss: 1.4177
# Epoch 27/100
# 46468/46468 [==============================] - 12s - loss: 1.4174
# Epoch 28/100
# 46468/46468 [==============================] - 12s - loss: 1.4175
# Epoch 29/100
# 46468/46468 [==============================] - 12s - loss: 1.4167
# Epoch 30/100
# 46468/46468 [==============================] - 12s - loss: 1.4158
# Epoch 31/100
# 46468/46468 [==============================] - 12s - loss: 1.4169
# Epoch 32/100
# 46468/46468 [==============================] - 12s - loss: 1.4156
# Epoch 33/100
# 46468/46468 [==============================] - 12s - loss: 1.4160
# Epoch 34/100
# 46468/46468 [==============================] - 12s - loss: 1.4155
# Epoch 35/100
# 46468/46468 [==============================] - 12s - loss: 1.4154
# Epoch 36/100
# 46468/46468 [==============================] - 12s - loss: 1.4156
# Epoch 37/100
# 46468/46468 [==============================] - 12s - loss: 1.4148
# Epoch 38/100
# 46468/46468 [==============================] - 12s - loss: 1.4150
# Epoch 39/100
# 46468/46468 [==============================] - 12s - loss: 1.4150
# Epoch 40/100
# 46468/46468 [==============================] - 12s - loss: 1.4141
# Epoch 41/100
# 46468/46468 [==============================] - 12s - loss: 1.4144
# Epoch 42/100
# 46468/46468 [==============================] - 12s - loss: 1.4149
# Epoch 43/100
# 46468/46468 [==============================] - 12s - loss: 1.4135
# Epoch 44/100
# 46468/46468 [==============================] - 12s - loss: 1.4143
# Epoch 45/100
# 46468/46468 [==============================] - 12s - loss: 1.4147
# Epoch 46/100
# 46468/46468 [==============================] - 12s - loss: 1.4136
# Epoch 47/100
# 46468/46468 [==============================] - 12s - loss: 1.4141
# Epoch 48/100
# 46468/46468 [==============================] - 12s - loss: 1.4149
# Epoch 49/100
# 46468/46468 [==============================] - 12s - loss: 1.4136
# Epoch 50/100
# 46468/46468 [==============================] - 12s - loss: 1.4138
# Epoch 51/100
# 46468/46468 [==============================] - 12s - loss: 1.4135
# Epoch 52/100
# 46468/46468 [==============================] - 12s - loss: 1.4132
# Epoch 53/100
# 46468/46468 [==============================] - 12s - loss: 1.4134
# Epoch 54/100
# 46468/46468 [==============================] - 12s - loss: 1.4137
# Epoch 55/100
# 46468/46468 [==============================] - 12s - loss: 1.4132
# Epoch 56/100
# 46468/46468 [==============================] - 12s - loss: 1.4138
# Epoch 57/100
# 46468/46468 [==============================] - 12s - loss: 1.4134
# Epoch 58/100
# 46468/46468 [==============================] - 12s - loss: 1.4134
# Epoch 59/100
# 46468/46468 [==============================] - 12s - loss: 1.4126
# Epoch 60/100
# 46468/46468 [==============================] - 12s - loss: 1.4127
# Epoch 61/100
# 46468/46468 [==============================] - 12s - loss: 1.4129
# Epoch 62/100
# 46468/46468 [==============================] - 12s - loss: 1.4129
# Epoch 63/100
# 46468/46468 [==============================] - 12s - loss: 1.4133
# Epoch 64/100
# 46468/46468 [==============================] - 12s - loss: 1.4125
# Epoch 65/100
# 46468/46468 [==============================] - 12s - loss: 1.4125
# Epoch 66/100
# 46468/46468 [==============================] - 12s - loss: 1.4123
# Epoch 67/100
# 46468/46468 [==============================] - 12s - loss: 1.4128
# Epoch 68/100
# 46468/46468 [==============================] - 12s - loss: 1.4124
# Epoch 69/100
# 46468/46468 [==============================] - 12s - loss: 1.4127
# Epoch 70/100
# 46468/46468 [==============================] - 12s - loss: 1.4117
# Epoch 71/100
# 46468/46468 [==============================] - 12s - loss: 1.4120
# Epoch 72/100
# 46468/46468 [==============================] - 12s - loss: 1.4128
# Epoch 73/100
#  - ETA: 2s - loss: 1.4145
# Epoch 74/100
# 46468/46468 [==============================] - 12s - loss: 1.4121
# Epoch 75/100
# 46468/46468 [==============================] - 12s - loss: 1.4118
# Epoch 76/100
# 46468/46468 [==============================] - 12s - loss: 1.4127
# Epoch 77/100
# 46468/46468 [==============================] - 12s - loss: 1.4119
# Epoch 78/100
# 46468/46468 [==============================] - 12s - loss: 1.4115
# Epoch 79/100
# 46468/46468 [==============================] - 12s - loss: 1.4124
# Epoch 80/100
# 46468/46468 [==============================] - 12s - loss: 1.4117
# Epoch 81/100
# 46468/46468 [==============================] - 12s - loss: 1.4112
# Epoch 82/100
# 46468/46468 [==============================] - 12s - loss: 1.4115
# Epoch 83/100
# 46468/46468 [==============================] - 12s - loss: 1.4121
# Epoch 84/100
# 46468/46468 [==============================] - 12s - loss: 1.4112
# Epoch 85/100
# 46468/46468 [==============================] - 12s - loss: 1.4120
# Epoch 86/100
# 46468/46468 [==============================] - 12s - loss: 1.4121
# Epoch 87/100
# 46468/46468 [==============================] - 12s - loss: 1.4111
# Epoch 88/100
# 46468/46468 [==============================] - 12s - loss: 1.4109
# Epoch 89/100
# 46468/46468 [==============================] - 12s - loss: 1.4121
# Epoch 90/100
# 46468/46468 [==============================] - 12s - loss: 1.4116
# Epoch 91/100
# 46468/46468 [==============================] - 12s - loss: 1.4116
# Epoch 92/100
# 46468/46468 [==============================] - 12s - loss: 1.4111
# Epoch 93/100
# 46468/46468 [==============================] - 12s - loss: 1.4119
# Epoch 94/100
# 46468/46468 [==============================] - 12s - loss: 1.4115
# Epoch 95/100
# 46468/46468 [==============================] - 12s - loss: 1.4107
# Epoch 96/100
# 46468/46468 [==============================] - 12s - loss: 1.4116
# Epoch 97/100
# 46468/46468 [==============================] - 12s - loss: 1.4119
# Epoch 98/100
# 46468/46468 [==============================] - 12s - loss: 1.4110
# Epoch 99/100
# 46468/46468 [==============================] - 12s - loss: 1.4111
# Epoch 100/100
# 46468/46468 [==============================] - 12s - loss: 1.4113

# %%
def print_example():
    seed_string="@"
    for i in range(3000):
        x=np.array([char_indices[c] for c in seed_string[-1:]])[np.newaxis,:]
        preds = model.predict(x, verbose=0)[0][-1]
        preds = preds/np.sum(preds)
        next_char = np.random.choice(chars, p=preds)
        seed_string = seed_string + next_char
    print(seed_string)

# %%
print_example()
# Out:
# @#rr#####rrr###r#rr##cM###rr#####Gr#rrr###8
# {.rrr#r##r#rrrrr#GSGdO##r###r###8[  {.rrr#rr#rr#r#GS##r####ScS##G'8CS#rr#8e2CSGr#####rr##rrr##Gr#rrr##8CS##r#rrrrrr#rrr##rrr##Gr#r##rrr####GS#r###rrrr#8*2[{{{{{{{{{{{{{{{{{{{{{{{{{.rr##Gr#8
# {{{{{{{{{{{{{{{{{{{{.rrr###8[ {.rrrrr#GSc#Gr#rrrr####rrrr#r#rr##r###r#1FS###r##Gr##r#1FS###rr#b#r###8D[{{{{{.###r#r#rrr####r#8}#8Mr##rr#######Sc#rrr#Gr##rr###r###rrr#####r#r#####r####r##r#r#8O#r#r#rr##rr#S##r#cM8_r#r#r####GS#8	{{{{{.#Gd###rrrrrrrr#r###rr####8_rr###8eDr#8
# .#####8_##r#r#1Fr###Gr####r#r###8dO##r#rr###r##r##rr#8Drr##rr#rr#rrr#r#8;rr##rr###r#rrr##r##rr###r#1Fr#rr####r#rr#r##GS#rrr#rr#r##rr#r#r#rrr##rr#Grr###8e##rrrr#rr#cScS#Gr###S####rr########rrr#c##rr####rrr###r#rrrrrrr#r#r########rr#GSc#Grrrrr#r###rr###SGr###r#1FScSGr#rr#rrrrrr##r#########rr#######cM#Grr###nr#Gr#8}#rrrr#Gr####8_#r#r###8e8Arr#r#8Drrrrr##r##rrrrrrrrr#4}#rrrrr#8grr##rr#rr#r#8Crr#rrr##Grrrr##rr#rrr#Gb#r#####rrrr##rrrrrr#rrrrrr#S####8CScMr###8_#r###8}rrr##rrr##r#r#8Drr##r#G8g#r##rr#rr#GdO#r#rrr##rr##rrr##r#r#rrrrrr####Gr#rr##r###r#rrrrrr####rr###rr##S###r###r##r###rr######r#r###r######Grr#Gd##r#8M#rr###r#8O#1Fr#rrr#SGS#r#8CScr###rrrr#r##r#####rr######r##rr#rrr##Grr#rr#8*2dO#rrr########r##rr#S##rr#r#######r#r#r#rr##8errr##rr#c#rrr##8_##rr##8_#r###rr###rrr#Gr###r#rrr#rrr##rr#rr#rrr#Grrrrrr#rrrr#####Gr#rrrrrr##c#rrr##r##GdO#####rrrrr##r#r##rr###r#r####r#rrr##rrr####rrrr###rr#S###rrrr#rr##rrrr#cM#8;W#####r###c#rr#r###rr##1FS###r#8M#r#cMr#r###r##rr#r#4M##r#rr####Grr#r#####r##r#8_#r##c#8*2Cr#r#rr#r#cS#rrrr###r####r####r##GdO######Grrr##Grr#Grrr#rr#r#####r#r#r#r####SGdrr#r#r###SGrr###rrrrrrr##rrr#rrr##rr#r##r##8M#rrrrrr#Grr#r#####GS#rrr#rrrrr#rr####1FS##r#r#r#r#r####r#r##r##r#rrrrr####rrrrrr#nrrr#r#r##r#8[ {{{{{{{{{.rrr#rr#rrr#b2Cr#Gr#cS#r#4eDr#rrr#rrr#######rrr##Gr##rr#rrrr##8
# {.##rrrrr#rrr#r#r#r#4Arr#r##cM###rrr##rr####Gr##r######r##8*2eDfS####rr#####8a#rr####Grrrr###r#r#Grr##1Fr##rrr#GdO###r##rrr#r#r#rr#Grr#r#Gr#rrrr#r#r#8*2O####8	{{{{.r#8dO###r#rrr#S##rr#rr#rr##Sc#b#4O######8e2}##r#rrrrr####r##r##Grrrr##r###r#r#8;#cr#r#rrrr#rrrr####rrr#8a2A
# {{{{{{{{{{{{{{.##Grr##r#rrrr##rrrr##r#rr#r##r###rrr#rrrr###r#rr#cM##rrrr###rrrr#rrrr#Gr##1FS#rrrr###r#4	{{{{{{{{{{{{{{{{{{{{{.#rrr##rrrr#####r#r##8Arrrr#rrr#rrr##r##rr#rr#######rr##Gd2a###cM####rrr##cM##Grr#r#rrr##rrr##r#rr#r##4	E2*2}##r#8;rrrr#####rrrr##rrr#1FS####1F*2arr##c1FS#rr####rr#r#8Dr####r###r##8
# .r#r##8Mr#rrrrrr###Grr#8_rr###r#r#r#rrrr##Grrr######Gr##r##ccS##rr#8	{{{{{{{{{{{{{{.r###rr###r#####rr##r##rrrr#r#r####rr#rr#rrrr##r#######rr#Grrr#rr##r###r##rr#rr#r##rrr####rrrrr###rr#rrr#Grrrrrr#rrr#rr#r#r#r#r###r#rrr##r#Grrr##rrr##r#rr#rr###1FS###r##rrr#rr##r#####r#rrrrrr###rrr#8d##rr##r##rr##r####r#r###rr##rr#Gr#r##r#r##GS#S##rrrrr##rr#r##########Grrrr#rr##r###r#rr##r#rrr#r#rrrr#rr#GfSc####rr###rr##r####r#r#r##rrrr#rr####Grr####rrr##rrrrrr#r####r#r##rrrr##r#GS####8g#r#r#rrrr######r###rrr##r#1FScM#r##r###r###S##r###rrrr##8	Er#r#r#rrrr##r#rrrr#r#8O#rrr#r#r#rrr#rr#r##rrrr#8D8}#rrrr##rr#rr#GbgS###r#r#GS###rr
